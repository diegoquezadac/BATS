# %%
from datasets import load_dataset, DatasetDict, Audio, load_from_disk
from transformers import pipeline
from evaluate import load
from tqdm import tqdm
from transformers.pipelines.pt_utils import KeyDataset
from transformers.models.whisper.english_normalizer import BasicTextNormalizer
from transformers import WhisperProcessor, Seq2SeqTrainer, Seq2SeqTrainingArguments
import torch
from dataclasses import dataclass
from typing import Any, Dict, List, Union
from transformers import WhisperForConditionalGeneration
from functools import partial
import torch._dynamo

torch._dynamo.config.suppress_errors = True

# %% [markdown]
# # Manual Preprocesing

# %%
common_voice = DatasetDict()

common_voice["train"] = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="train")
common_voice["validation"] = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="validation")
common_voice["test"] = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="test")

common_voice = common_voice.select_columns(["audio", "sentence"])
# Out:
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
processor = WhisperProcessor.from_pretrained(
    "openai/whisper-small"
)

# %%
sampling_rate = processor.feature_extractor.sampling_rate
common_voice = common_voice.cast_column("audio", Audio(sampling_rate=sampling_rate))

# %%
def prepare_dataset(example):
    audio = example["audio"]

    example = processor( #compute the mel spectogram
        audio=audio["array"],
        sampling_rate=audio["sampling_rate"],
        text=example["sentence"],
    )

    # compute input length of audio sample in seconds
    example["input_length"] = len(audio["array"]) / audio["sampling_rate"]

    return example

# %% [markdown]
# ## Train

# %%
common_voice['train'] = common_voice['train'].map(
    prepare_dataset,remove_columns=common_voice["train"].column_names, num_proc=4,
)

common_voice['train'].save_to_disk("datasets/common_voice/validation")

# %% [markdown]
# ## Valid

# %%
common_voice['validation'] = common_voice['validation'].map(
    prepare_dataset, remove_columns=common_voice.column_names["validation"], num_proc=30
)

common_voice['validation'].save_to_disk('datasets/common_voice/validation')
# Out:
# Map (num_proc=30):   0%|          | 0/16354 [00:00<?, ? examples/s]
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %% [markdown]
# ## Test

# %%
common_voice['test'] = common_voice['test'].map(
    prepare_dataset, remove_columns=common_voice.column_names["test"], num_proc=20
)

common_voice['test'].save_to_disk('datasets/common_voice/test')
# Out:
# Map (num_proc=20):   0%|          | 0/16354 [00:00<?, ? examples/s]
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)
# Saving the dataset (0/32 shards):   0%|          | 0/16354 [00:00<?, ? examples/s]

# %% [markdown]
# # Fine Tuning

# %%
common_voice = DatasetDict()

#common_voice["train"] = load_from_disk('datasets/common_voice/train')
common_voice["validation"] = load_from_disk('datasets/common_voice/validation')
common_voice["test"] = load_from_disk('datasets/common_voice/test')
# Out:
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
common_voice
# Out:
# DatasetDict({
#     validation: Dataset({
#         features: ['input_features', 'labels', 'input_length'],
#         num_rows: 16354
#     })
#     test: Dataset({
#         features: ['input_features', 'labels', 'input_length'],
#         num_rows: 16354
#     })
# })

# %%
max_input_length = 30.0

def is_audio_in_length_range(length):
    return length < max_input_length

# %%
common_voice = common_voice.filter(
    is_audio_in_length_range,
    input_columns=["input_length"],
)

# %%
@dataclass
class DataCollatorSpeechSeq2SeqWithPadding:
    processor: Any

    def __call__(
        self, features: List[Dict[str, Union[List[int], torch.Tensor]]]
    ) -> Dict[str, torch.Tensor]:
        # split inputs and labels since they have to be of different lengths and need different padding methods
        # first treat the audio inputs by simply returning torch tensors
        input_features = [
            {"input_features": feature["input_features"][0]} for feature in features
        ]
        batch = self.processor.feature_extractor.pad(input_features, return_tensors="pt")

        # get the tokenized label sequences
        label_features = [{"input_ids": feature["labels"]} for feature in features]
        # pad the labels to max length
        labels_batch = self.processor.tokenizer.pad(label_features, return_tensors="pt")

        # replace padding with -100 to ignore loss correctly
        labels = labels_batch["input_ids"].masked_fill(
            labels_batch.attention_mask.ne(1), -100
        )

        # if bos token is appended in previous tokenization step,
        # cut bos token here as it's append later anyways
        if (labels[:, 0] == self.processor.tokenizer.bos_token_id).all().cpu().item():
            labels = labels[:, 1:]

        batch["labels"] = labels

        return batch

# %%
processor = WhisperProcessor.from_pretrained(
    "openai/whisper-small"
)

# %%
data_collator = DataCollatorSpeechSeq2SeqWithPadding(processor=processor)

# %%
metric = load("wer")

# %%
normalizer = BasicTextNormalizer()


def compute_metrics(pred):
    pred_ids = pred.predictions
    label_ids = pred.label_ids

    # replace -100 with the pad_token_id
    label_ids[label_ids == -100] = processor.tokenizer.pad_token_id

    # we do not want to group tokens when computing the metrics
    pred_str = processor.batch_decode(pred_ids, skip_special_tokens=True)
    label_str = processor.batch_decode(label_ids, skip_special_tokens=True)

    # compute orthographic wer
    wer_ortho = 100 * metric.compute(predictions=pred_str, references=label_str)

    # compute normalised WER
    pred_str_norm = [normalizer(pred) for pred in pred_str]
    label_str_norm = [normalizer(label) for label in label_str]
    # filtering step to only evaluate the samples that correspond to non-zero references:
    pred_str_norm = [
        pred_str_norm[i] for i in range(len(pred_str_norm)) if len(label_str_norm[i]) > 0
    ]
    label_str_norm = [
        label_str_norm[i]
        for i in range(len(label_str_norm))
        if len(label_str_norm[i]) > 0
    ]

    wer = 100 * metric.compute(predictions=pred_str_norm, references=label_str_norm)

    return {"wer_ortho": wer_ortho, "wer": wer}

# %%
model = WhisperForConditionalGeneration.from_pretrained("openai/whisper-small")

# %%
# disable cache during training since it's incompatible with gradient checkpointing
model.config.use_cache = False

# set language and task for generation and re-enable cache
model.generate = partial(
    model.generate, language="en", task="transcribe", use_cache=True
)

# %%
training_args = Seq2SeqTrainingArguments(
    output_dir="./bats",  # name of output directory
    resume_from_checkpoint=True,
    per_device_train_batch_size=1, #The batch size for training.
    gradient_accumulation_steps=16,  #Number of updates steps to accumulate the gradients for, before performing a backward/update pass, increase by 2x for every 2x decrease in batch size
    optim="adafactor", 
    torch_compile=True,
    learning_rate=1e-5,
    lr_scheduler_type="constant_with_warmup",
    warmup_steps=50,
    max_steps=200,  # increase to 4000 if you have your own GPU or a Colab paid plan
    logging_steps=25, #Number of update steps between two logs
    save_steps=10, #model checkpoint save frequency
    seed=42,
    gradient_checkpointing=True, #use gradient checkpointing to save memory at the expense of slower backward pass.
    evaluation_strategy="steps", #The evaluation strategy to adopt during training.
    per_device_eval_batch_size=1, #The batch size for evaluation.
    eval_steps=10,
    report_to=["tensorboard"], #The list of integrations to report the results and logs to.
    load_best_model_at_end=True,
    #metric_for_best_model="wer",
    #greater_is_better=False, #specify if better models should have a greater metric or not
    push_to_hub=False, #Whether or not to push the model to the Hub every time the model is saved
    prediction_loss_only=True, #When performing evaluation and generating predictions, only returns the loss
    eval_accumulation_steps = 1,
)
# Out:
# The speedups for torchdynamo mostly come wih GPU Ampere or higher and which is not detected here.

# %%
trainer = Seq2SeqTrainer(
    args=training_args,
    model=model,
    train_dataset=common_voice["validation"],
    eval_dataset=common_voice["test"],
    data_collator=data_collator,
    #compute_metrics=compute_metrics,
    tokenizer=processor,
)

# %%
trainer.train()
# Out:
#   0%|          | 0/200 [00:00<?, ?it/s]
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/models/whisper/modeling_whisper.py line 1626
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING]   File "/Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/_inductor/graph.py", line 906, in init_wrapper_code
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING]     self.wrapper_code = wrapper_code_gen_cls()
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] TypeError: 'NoneType' object is not callable
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:39,017] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT shift_tokens_right /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/models/whisper/modeling_whisper.py line 93
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING]   File "/Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/_inductor/graph.py", line 906, in init_wrapper_code
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING]     self.wrapper_code = wrapper_code_gen_cls()
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] TypeError: 'NoneType' object is not callable
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:39,095] torch._dynamo.convert_frame: [WARNING]
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/models/whisper/modeling_whisper.py line 1218
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING]   File "/Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/_inductor/graph.py", line 906, in init_wrapper_code
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING]     self.wrapper_code = wrapper_code_gen_cls()
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] TypeError: 'NoneType' object is not callable
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:40,378] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT _make_causal_mask /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/modeling_attn_mask_utils.py line 119
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING]   File "/Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/_inductor/graph.py", line 906, in init_wrapper_code
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING]     self.wrapper_code = wrapper_code_gen_cls()
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] TypeError: 'NoneType' object is not callable
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,060] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] WON'T CONVERT forward /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/models/whisper/modeling_whisper.py line 308
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] due to:
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] Traceback (most recent call last):
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING]   File "/Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/_inductor/graph.py", line 906, in init_wrapper_code
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING]     self.wrapper_code = wrapper_code_gen_cls()
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] TypeError: 'NoneType' object is not callable
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING]
# [2023-11-08 00:17:41,112] torch._dynamo.convert_frame: [WARNING]
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/checkpoint.py:429: UserWarning: torch.utils.checkpoint: please pass in use_reentrant=True or use_reentrant=False explicitly. The default value of use_reentrant will be updated to be False in the future. To maintain current behavior, pass use_reentrant=True. It is recommended that you use use_reentrant=False. Refer to docs for more details on the differences between the two variants.
#   warnings.warn(
#   0%|          | 0/16349 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/fcisternas/Desktop/BATS/hf_pretrained.ipynb Cell 27 line 1
# ----> <a href='vscode-notebook-cell:/Users/fcisternas/Desktop/BATS/hf_pretrained.ipynb#X34sZmlsZQ%3D%3D?line=0'>1</a> trainer.train()
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:1555, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    1553         hf_hub_utils.enable_progress_bars()
#    1554 else:
# -> 1555     return inner_training_loop(
#    1556         args=args,
#    1557         resume_from_checkpoint=resume_from_checkpoint,
#    1558         trial=trial,
#    1559         ignore_keys_for_eval=ignore_keys_for_eval,
#    1560     )
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:1922, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    1919     self.state.epoch = epoch + (step + 1 + steps_skipped) / steps_in_epoch
#    1920     self.control = self.callback_handler.on_step_end(args, self.state, self.control)
# -> 1922     self._maybe_log_save_evaluate(tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    1923 else:
#    1924     self.control = self.callback_handler.on_substep_end(args, self.state, self.control)
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:2271, in Trainer._maybe_log_save_evaluate(self, tr_loss, model, trial, epoch, ignore_keys_for_eval)
#    2269         metrics.update(dataset_metrics)
#    2270 else:
# -> 2271     metrics = self.evaluate(ignore_keys=ignore_keys_for_eval)
#    2272 self._report_to_hp_search(trial, self.state.global_step, metrics)
#    2274 # Run delayed LR scheduler now that metrics are populated
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer_seq2seq.py:165, in Seq2SeqTrainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix, **gen_kwargs)
#     162     gen_kwargs["num_beams"] = self.args.generation_num_beams
#     163 self._gen_kwargs = gen_kwargs
# --> 165 return super().evaluate(eval_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:3011, in Trainer.evaluate(self, eval_dataset, ignore_keys, metric_key_prefix)
#    3008 start_time = time.time()
#    3010 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3011 output = eval_loop(
#    3012     eval_dataloader,
#    3013     description="Evaluation",
#    3014     # No point gathering the predictions if there are no metrics, otherwise we defer to
#    3015     # self.args.prediction_loss_only
#    3016     prediction_loss_only=True if self.compute_metrics is None else None,
#    3017     ignore_keys=ignore_keys,
#    3018     metric_key_prefix=metric_key_prefix,
#    3019 )
#    3021 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    3022 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:3241, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3235 if (
#    3236     args.eval_accumulation_steps is not None
#    3237     and (step + 1) % args.eval_accumulation_steps == 0
#    3238     and (self.accelerator.sync_gradients or version.parse(accelerate_version) > version.parse("0.20.3"))
#    3239 ):
#    3240     if losses_host is not None:
# -> 3241         losses = nested_numpify(losses_host)
#    3242         all_losses = losses if all_losses is None else np.concatenate((all_losses, losses), axis=0)
#    3243     if preds_host is not None:
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer_pt_utils.py:161, in nested_numpify(tensors)
#     158 if isinstance(tensors, Mapping):
#     159     return type(tensors)({k: nested_numpify(t) for k, t in tensors.items()})
# --> 161 t = tensors.cpu()
#     162 if t.dtype == torch.bfloat16:
#     163     # As of Numpy 1.21.4, NumPy does not support bfloat16 (see
#     164     # https://github.com/numpy/numpy/blob/a47ecdea856986cd60eabbd53265c2ca5916ad5d/doc/source/user/basics.types.rst ).
#     165     # Until Numpy adds bfloat16, we must convert float32.
#     166     t = t.to(torch.float32)
#
# KeyboardInterrupt:

# %%
metrics = trainer.evaluate()

# %%
preds = trainer.predict(common_voice["test"][0])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /Users/fcisternas/Desktop/BATS/hf_pretrained.ipynb Cell 29 line 1
# ----> <a href='vscode-notebook-cell:/Users/fcisternas/Desktop/BATS/hf_pretrained.ipynb#Y104sZmlsZQ%3D%3D?line=0'>1</a> preds = trainer.predict(common_voice["test"][0])
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer_seq2seq.py:228, in Seq2SeqTrainer.predict(self, test_dataset, ignore_keys, metric_key_prefix, **gen_kwargs)
#     225     gen_kwargs["num_beams"] = self.args.generation_num_beams
#     226 self._gen_kwargs = gen_kwargs
# --> 228 return super().predict(test_dataset, ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix)
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:3087, in Trainer.predict(self, test_dataset, ignore_keys, metric_key_prefix)
#    3084 start_time = time.time()
#    3086 eval_loop = self.prediction_loop if self.args.use_legacy_prediction_loop else self.evaluation_loop
# -> 3087 output = eval_loop(
#    3088     test_dataloader, description="Prediction", ignore_keys=ignore_keys, metric_key_prefix=metric_key_prefix
#    3089 )
#    3090 total_batch_size = self.args.eval_batch_size * self.args.world_size
#    3091 if f"{metric_key_prefix}_jit_compilation_time" in output.metrics:
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/transformers/trainer.py:3190, in Trainer.evaluation_loop(self, dataloader, description, prediction_loss_only, ignore_keys, metric_key_prefix)
#    3188 observed_num_examples = 0
#    3189 # Main evaluation loop
# -> 3190 for step, inputs in enumerate(dataloader):
#    3191     # Update the observed num examples
#    3192     observed_batch_size = find_batch_size(inputs)
#    3193     if observed_batch_size is not None:
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/accelerate/data_loader.py:451, in DataLoaderShard.__iter__(self)
#     449 # We iterate one batch ahead to check when we are at the end
#     450 try:
# --> 451     current_batch = next(dataloader_iter)
#     452 except StopIteration:
#     453     yield
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/data/dataloader.py:630, in _BaseDataLoaderIter.__next__(self)
#     627 if self._sampler_iter is None:
#     628     # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     629     self._reset()  # type: ignore[call-arg]
# --> 630 data = self._next_data()
#     631 self._num_yielded += 1
#     632 if self._dataset_kind == _DatasetKind.Iterable and \
#     633         self._IterableDataset_len_called is not None and \
#     634         self._num_yielded > self._IterableDataset_len_called:
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/data/dataloader.py:674, in _SingleProcessDataLoaderIter._next_data(self)
#     672 def _next_data(self):
#     673     index = self._next_index()  # may raise StopIteration
# --> 674     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#     675     if self._pin_memory:
#     676         data = _utils.pin_memory.pin_memory(data, self._pin_memory_device)
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in _MapDatasetFetcher.fetch(self, possibly_batched_index)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# File ~/miniconda3/envs/bats/lib/python3.10/site-packages/torch/utils/data/_utils/fetch.py:51, in <listcomp>(.0)
#      49         data = self.dataset.__getitems__(possibly_batched_index)
#      50     else:
# ---> 51         data = [self.dataset[idx] for idx in possibly_batched_index]
#      52 else:
#      53     data = self.dataset[possibly_batched_index]
#
# KeyError: 0

# %% [markdown]
# # inference

# %%
cv_11_train = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="train")
cv_11_test = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="test")
cv_11_val = load_dataset("mozilla-foundation/common_voice_11_0", "en", split="validation")
# Out:
# /Users/fcisternas/miniconda3/envs/bats/lib/python3.10/site-packages/datasets/table.py:1421: FutureWarning: promote has been superseded by mode='default'.
#   table = cls._concat_blocks(blocks, axis=0)

# %%
device = "mps"

pipe = pipeline(
    "automatic-speech-recognition",
    model=model,
    torch_dtype = torch.float16,
    device=device,
)
# Out:
# Special tokens have been added in the vocabulary, make sure the associated word embeddings are fine-tuned or trained.

# %%
all_predictions = []

# run streamed inference
for prediction in tqdm(
    pipe(
        KeyDataset(cv_11_test, "audio"),
        max_new_tokens=128,
        generate_kwargs={"task": "transcribe"},
        batch_size=16,
    ),
    total=len(cv_11_test),
):
    all_predictions.append(prediction["text"])
# Out:
#   0%|          | 0/16354 [00:00<?, ?it/s]
# 100%|██████████| 16354/16354 [1:52:09<00:00,  2.43it/s]

# %%
all_predictions
# Out:
# [' Joe Keaton disapproved of films and Buster also had reservations about the medium.',
#  " She'd be alright.",
#  ' Six.',
#  ' All is well, that ends well.',
#  ' It is a busy market town that serves a large surrounded area.',
#  ' The team had Olympic champion Carolina Marin in the squad for the season.',
#  ' Do you mean it?',
#  ' The new patch is less invasive than the old one, but still causes regression.',
#  ' How is Mozilla going to handle ambiguities like Q and Q?',
#  ' وشهد بسيطة ونفاقتي',
#  ' No one near the remote machine you could ring.',
#  ' Sauce for the juice is sauce for the condor.',
#  ' Grafs started writing songs when she was 4 years old.',
#  ' Ezenkel Maik Shula was the former age coach at Alabama.',
#  ' Kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa k',
#  ' The long-lived Bleach still stands today.',
#  ' There was nothing to hold him back except himself.',
#  ' The meat processing and construction industries would be allowed to operate with radius personal.',
#  " Cole's Branch is underlaid by the Deep River Basin.",
#  ' We spoke often.',
#  ' He was Protestant.',
#  ' This is the depression loop puzzle.',
#  ' The ladder on the fire truck was not low enough.',
#  ' I will tell her what we decided.',
#  ' These and the other leaders are advised and supported by the adult leaders.',
#  ' Hello, this is one of my, an experiment that belongs to the class of notes, notes, though molecular, great upper notes.',
#  ' Good things come in small packages.',
#  ' Boles is studying chemical engineering at the University College Dublin.',
#  ' It is a member theater of the Union of the Theaters of Europe.',
#  ' All three battalions were equipped with captured ranged tanks.',
#  ' You want to take this outside.',
#  ' She joined the K patrol line and patrolled off on Alaska Island.',
#  ' The immersion in hot water also kills the sick burn.',
#  ' She married her business partner Stephen Lee.',
#  ' The attack on your road driver overstrained our senior administrator.',
#  ' Do you want me?',
#  ' That would be funny if he did.',
#  ' Eight national Paralympic Committee quotas and three individual athlete quotas were secured.',
#  ' Although she had flowers and applause may be said she was not content',
#  ' Add the column and put the sum here.',
#  ' They perfectly illuminate the flowerbeds of gardens.',
#  ' A mansion was usually set on a one square.',
#  ' Alston commented that he felt the cartoonist might have had some racial intent.',
#  ' He was the chief clerk of the Chicago and Northwestern Railroad.',
#  ' Doing a handstand needs a lot of practice to learn.',
#  ' Man in red t-shirt and baseball cap viewed from above he has a pile of posters.',
#  ' The two films were then released within one day of each other.',
#  ' What did he say his name was asked the captain?',
#  ' He has German ancestry from his paternal side.',
#  ' Yes',
#  ' Benim yanımda kafalı oturmanıza gerek yok. Başınızı açabilirsiniz.',
#  " After experiencing a mind-blowing sensual orgy, Mike's was sure he had taken out of her dose.",
#  ' Religious festivals include the Muslim Eids and the Christian Christmas and Easter.',
#  ' What do you advise, sir?',
#  ' Charles looked on, angry that there was nothing he could do.',
#  ' She had more personal exhibitions and participated in group exhibitions as well.',
#  ' The Manifest tool made apparent the philosophical changes that Abbas has undergone.',
#  ' She was also appointed the owner easily distinguished professor of medicine.',
#  ' Karina Shrunaf of dancing with the stars hosted the following month.',
#  ' It is inhibited by the pneumotoxic center.',
#  ' His white green and many friends.',
#  ' An important person in the life of Amida Cross was the painter Jimmy Montigny.',
#  " In the United States, federal vehicle fleets refer to the federal government's vehicles.",
#  ' كانت مجموعة من بارا سويتر',
#  ' The prints are then delivered to the customers.',
#  ' In spite of this I still believe that there were men in Mars.',
#  ' The land was filled, I had to find some other way to end the living.',
#  ' The prints of mud and clay were on the floor.',
#  ' How can we live?',
#  ' I pointed out Mars a bright dot of light.',
#  ' He ended up running to the bars which fortified the windows of the first floor.',
#  ' I know why I want to get back to my flock, he thought.',
#  ' Many notable problems and study composers are also international judges including Gendrick Kasparian.',
#  ' Many of the supporting characters present an unflattering portrayal of colonial life in Bahaduria.',
#  ' You should see the other guy. Spicefully, how good at fighting he is.',
#  ' He is of African American and Italian descent.',
#  " That's not Carson Spinks.",
#  ' Some rules of thumb are also accepted in the codes.',
#  " L'orange is listed as a Swiss heritage site of national significance.",
#  ' I have never in life hit a tennis ball.',
#  ' Ukrainia, Ukrainia, 6 kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa',
#  ' He is the first known and undisputed member of the Jeminids.',
#  ' Lion Rock is located northwest of Wong Tai Sing.',
#  ' At dusk the Greek question Frank was broken',
#  ' Her father is sure to inherit.',
#  ' We should not take for granted how fortunate we have been.',
#  ' Topical and up to the minute, ye.',
#  ' The farmer works the soil and produces grain.',
#  " Since I've gotten a dog, the regular visits of the fox have stopped.",
#  ' His speech ended with a standing ovation.',
#  ' 8',
#  ' The reserve is in pristine condition with almost no human habitation.',
#  ' The wind told me that you know about love. The boy said to the sun.',
#  ' JLs began playing jazz trumpet but everyone sure they should check to blues, guitar.',
#  ' This is the context in which the film begins.',
#  ' तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो तो त',
#  ' The little pink ones are so cute.',
#  ' The student is colored with their crayons.',
#  ' It seemed to him that I felt to earth about 1.0 miles east here.',
#  " As such it is, they's uniform but with irregular face polygons.",
#  ' Yours, hair and ref.',
#  ' He took the first part and handed it to the Muck.',
#  ' He is a right handed batsman and a left arm slow bowler.',
#  ' Cador is also said to be a Roman stock.',
#  ' Where will you go?',
#  ' Only John, when himself surpassed Macbeth, ensigns in this movie.',
#  ' It was opened in July of that year.',
#  ' Verrushling is a talented fan manager. She works in Vienna.',
#  ' They were eliminated in the fourth episode.',
#  ' Municine means near the island',
#  ' The honor of the dwelling was not amused.',
#  ' All of this activity in Milwaukee was in Norway unique.',
#  ' William Barnes, the poet also lived in Starr, Mr. Newton.',
#  " By then, it's happening going through the steps in unison.",
#  " I'm so glad to see you.",
#  ' Corn cockle is an attractive plant and its seeds are still commercially available to gardeners.',
#  ' Davio De Oro is headed by its governor as the chief executive.',
#  ' The Swedish actress Anna Norri instructed her in drama.',
#  ' तेंशी लुगदाः',
#  ' Agni agrees to let Toggedeta film his revenge on Doma in exchange for training.',
#  ' What was he like?',
#  " Luckily the dagger couldn't penetrate the bulletproof vest.",
#  ' Like everybody learns, you sip.',
#  ' This has become a bit of a cult in Romania.',
#  ' These other film roles include Who Done It.',
#  ' How often has the train been late?',
#  ' Dia sekarang seorang pembantu jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika jika',
#  ' To increase the popularity in public opinion polls, the politicians started a campaign.',
#  ' She was the first woman senator to die in office.',
#  ' Where is it then?',
#  ' Always ask an objective question.',
#  " I think I'm looking for stars.",
#  ' People from all over have come to test its beer stew.',
#  ' More discussion is needed on how it will be financed.',
#  ' A soldier ring a pink scarf pierced out of the top of a vehicle.',
#  ' Passive surveillance is often incomplete because of the limited reporting incentives.',
#  ' Princess Phyllis herself also contributed personally to the construction of the temple.',
#  ' And Baleor refers to a convincing disjointed man.',
#  ' He became chief of the Army personnel department.',
#  " I can't work for the wrestler today. The boy answered.",
#  " I'd like to order some cinnamon pretzels please.",
#  ' The boy was also saddened, his friend was in pursuit of his destiny.',
#  ' Women form less than half of the group.',
#  ' Man play football as a crowd watches.',
#  ' How about once more around the park?',
#  ' It is postponed that there were other visits.',
#  ' The video will go on and on forever.',
#  ' The genus name is given in honor of Queen Victoria of the United Kingdom.',
#  ' esong.emate',
#  ' Nickflane was raised by his mother in citrate, Massachusetts, as server of Boston.',
#  ' These plants are hermaphroditic.',
#  ' Local branches throughout Slovakia were primarily engaged in public education and cultural activities.',
#  ' The current representative for the district is Democrat Karen Power of Milwaukee.',
#  ' The major industry has been slate mining.',
#  " Today's signature flight support services private aircraft in this area.",
#  ' This process is intense and often lengthy.',
#  ' He also was the elected senator of Kuzestan.',
#  ' The line appears to be on the tube map as an orange destroyer.',
#  ' Armonne immigrated to the United States from France and sold hats as an occupation.',
#  ' What can they approve is that',
#  ' The crew also activated one group of the payload B getaways special experiments.',
#  ' The Earth-Tasher-Mosque General',
#  ' They had a lot to devourish.',
#  ' It also supports landscape orientation on multiple typefaces.',
#  ' They displaced at normal load and at deep load.',
#  ' Every day was there to be lived. Our two marks once departure from this world.',
#  " Let's go to Arba",
#  ' Potato chips are thinly sliced fried potatoes eaten as a snack.',
#  ' The movie White Christmas also started being Crosby and Daniel K.',
#  ' The staircase survives in the Sworn Hotel in Bedford.',
#  ' Only six of the planned ten episodes were produced.',
#  ' We are giving Tim no rest.',
#  ' Double swimming use rulers to shape the can, lid and the final double seal.',
#  ' Throughout the entire day we will be on the lookout for our enemies',
#  ' The palace was rebuilt with the same stones.',
#  " Il était employé dans l'industrie de coal avant d'assumer l'office.",
#  " The village's topography is mostly flat.",
#  ' Plastic surgery has become more popular.',
#  ' The tracking reference did not work.',
#  ' But you are joking.',
#  ' Those are the original parts of the hospital are now administrative and social accommodation.',
#  ' She wanted to do penance.',
#  ' With no weapons the only attack option open to Embossed Arial Dreaming.',
#  ' It was in 6200 and the Lord and Tenant in Chief was Shattis Buri Abi.',
#  ' After being coach, he held other functions within Dutch speed skating.',
#  " That's cranks do not provide had big feedback.",
#  ' It was a tent like many at the Oasis.',
#  ' Thank you.',
#  ' Rosemary was born in Uganda and she attended local primary and secondary schools.',
#  " This blurry tomography doesn't help me a lot with the diagnosis.",
#  ' Sunburn can be avoided by applying sunscreen or by staying in the shadows.',
#  ' Falls on the other hand can occur only while the ball is in play.',
#  ' In pure vacuum some weak scattering of light by light exists as well.',
#  ' Since living of this, he has attended a number of other events of significance.',
#  ' فتیمہ دا گول سیٹ اورٹنگھر آئیز',
#  ' you',
#  ' She also taught journalism at the University of California at Berkeley.',
#  ' Still waters run deep.',
#  ' The university is a member of several organizations of colleges and universities.',
#  ' These charms have a mellow sound.',
#  ' No one has ever done it before.',
#  ' What game do you want to play?',
#  ' The completed chartering contract is known as the Charter Party.',
#  ' Its shape and coloration is reminiscent of a brown trout.',
#  ' Maybe the church with the sycamore growing from within had been haunted.',
#  ' She also is a faculty member at the Tangeload Music Center.',
#  ' There are three amino acid residues responsible for this G to M phase transition.',
#  ' I will go right after it.',
#  ' You need to know to build your own custom environment.',
#  ' It has ornamental vigas.',
#  ' An awesome picture of a young woman jumping in the air.',
#  ' Sure, see you there!',
#  ' He was mayor of Palermo for three months.',
#  ' Tina has started playing hockey for the other Buenos Aires in Argentina.',
#  ' Such domain names are often linked to news and current events.',
#  ' Some concurrent programming models include core processes and deterministic concurrency.',
#  ' Yes?',
#  ' some stones are worth the wreckage',
#  ' Bye!',
#  ' Her colleagues may also require treatment for other psychotropic drug addictions and drug dependence.',
#  ' This convention is a natural.',
#  ' He was awarded the Order of the Red Star.',
#  ' So he decided to choose the area for opening for cultivation.',
#  ' Three.',
#  ' The final medal tally was led by host Vietnam, followed by Thailand and Indonesia. Full stop.',
#  ' The tea was a little bit too hot.',
#  ' Sisters Kimberly and Tiffany and Brother Ryan',
#  ' Clams are small round soft and tasty.',
#  ' This song was composed in Sufi genre.',
#  ' It continues a tauway until its turn is in your side.',
#  " I'm going to cut the shit out of this.",
#  ' Thailand turned out to be a very satisfying holiday.',
#  " The series' writers included McGovern, Danny Broeklash, Andy Snutter and Sean Duggan.",
#  ' The tower block picture is the south face of Castro house on city road London',
#  ' I think we must get that done. However, it can never be recovered from the entire relative parallel.',
#  ' On the eastern and opposite of the road of the Gate of Glorus Harmony',
#  ' Morse found fame relatively late in life.',
#  ' Arizona Republican State Senator Karen Johnson joined the protest in support.',
#  ' Like a note for a horse.',
#  ' Zero.',
#  ' This would indicate an activation of seismic activity in the sea of Marmara.',
#  ' Following is Allah, civil was an ancient Rome.',
#  ' Pro-notal disk with slightly opaque Durham.',
#  ' Originally, the finale for the sixth season was promoted as a cliffhanger.',
#  ' ლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლ�',
#  ' The most successful athletic program is wrestling.',
#  ' Yoniko Snikayas clinjt the championship by winning the regular season.',
#  ' At these dimensions, it is large enough to be seen from space.',
#  ' The internet is built upon many protocols which complement each other perfectly.',
#  ' Wait for the end of the world.',
#  ' Finally, the beaters began playing at the jack on occasions.',
#  ' 20 down, down is all of it.',
#  ' His grandmother Diana Davison was one of the first female racing drivers in Australia.',
#  ' It worked closely with the General Federation of the Municipal Administration.',
#  ' She also studied photography at the Parsons School of Art and Design in Paris.',
#  ' Drake grew up in Texas.',
#  ' She would let a turn phase after a request phase turn.',
#  ' Transom rest on the lower cord of the panels and clamps hold them together.',
#  ' He soon focused to specialize in seven right cases.',
#  ' This desert was once a sea, he said.',
#  ' It included a new production of passion directed by Jamie Lloyd.',
#  ' A handsome shoe often pinches the foot.',
#  ' He voyaged on a ship called the Beagle.',
#  " I can reassure you that we won't retreat until the oil, until the peace is secured.",
#  ' Initially, he joined the North, bought new news as a reporter.',
#  ' Hearting sees one of ten children.',
#  ' Inako accompanies her as they tail the group to collect evidence.',
#  ' His father and brother were murdered after selection.',
#  ' Another is that it was struck by lightning which started the fire.',
#  ' And the big Persian knew of his existence before he did of hers.',
#  ' He previously played at Boston College.',
#  ' He delights in quoting and adapting literature to describe his experiences.',
#  " Good afternoon, Sal and Joda's pitching arm is Kory, Wilson's series Jeopardy.",
#  " Toby said he's gonna see you, he's XY.",
#  " I can reassure you that we won't retreat until the piece is secured.",
#  " I don't blame you.",
#  ' He jumped up and turned to plea to face the imagine terror screaming get back',
#  ' He is reserved and serious, which is a further mark of respectability.',
#  ', నినినినినినినినినినినినినినినినినినినినినినినినినినినినినినిన�',
#  ' My dad is a Republican.',
#  ' Red Eye never committed a more outrageous deed.',
#  ' Good playgrounds have more small two-offer than streams and slides.',
#  ' He had also seen one European who apparently was content not to leave.',
#  ' The region remains neglected by the state government and the district administration.',
#  ' Newborn Fendless Porpoises are reported to in length.',
#  ' No change is permissible in regards to festivals and dates.',
#  ' It also has a visitor center and an interpretive exhibit.',
#  ' It was also the site of several civil strife and labor conflicts.',
#  ' Sorry the test period expired.',
#  ' And it is a six minute video.',
#  ' He held the office of captain of Royal Company of Artus.',
#  ' As the player grows closer to Pikachu, more activities become available.',
#  ' However, there are some issues that came out full-color to celebrate certain anniversaries.',
#  ' It is private property and not open to the public.',
#  ' The forest burned for 13 days.',
#  ' You can drive in and participate in the game by the flag.',
#  ' I accuse this man of being a faker.',
#  ' There was a loud shriek from a woman standing behind us.',
#  ' Neither does she appear in the Ordnance Survey Memor for Karak Burgess.',
#  ' The prototype was converted into a factory fire engine for the Peugeot plan.',
#  ' He also wrote in the daily newspaper El Watan.',
#  " It's not D-Lang.",
#  ' Kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa k',
#  ' His hands began to tremble and the woman sensed it.',
#  ' The Taowan school system is united with neighboring Warren Rold Island.',
#  ' They sometimes have a central tune which some of the strains are based on.',
#  ' You might hear plot families more than typepapers even though they mean the same thing.',
#  ' And men with white beard is writing in a book while two women look on.',
#  " Rudenko was a follower of Paul Brokker's French School of Anthropology.",
#  ' He was also involved in mysticism.',
#  ' Let my life of chess',
#  ' Cave diving tourism is generally serviced by specialists, dive guides, and instructors.',
#  ' She grew up singing in church and school chores.',
#  ' Charlie was now alone.',
#  ' He secondary studied at Hunan Provincial First High School.',
#  ' I wrote my bachelor thesis with latex.',
#  ' I have stuck it back to there.',
#  ' Se tente muito que eu vier visível.',
#  ' It is a most valuable stump in the world.',
#  ' The Queen Mary Salter, the Tolls appear to show five.',
#  ' Her husband joined with her in establishing a law firm together.',
#  ' We did this by obscuring the reflector with a mask under vertical slits.',
#  ' Three people were killed in the attack.',
#  ' Further, there is no mention of the comet in Chinese literature of the time.',
#  ' The friend is easier lost than found.',
#  ' He was born at Landsberg on the Lich.',
#  ' 늦을 끊임없이',
#  " So, I'm going to subscribe to the channel.",
#  ' She would later be promoted to captain.',
#  'みげってもらった気がする',
#  ' Foaster had died approximately 3 weeks in her life.',
#  " The win was one of only two for the cent in this man's season.",
#  ' The plastic barrier shattered.',
#  ' This song was meant to make the general public aware of heroes.',
#  ' It was seen early in the morning, Russian or East War.',
#  ' It is found in the Indian subcontinent China and Southeast Asia.',
#  ' Getting to play someone as unrestricted as a vampire is a thrill, she says.',
#  ' A man holding a newborn baby in a blue, pink, and white blanket.',
#  ' One week later she was released after successfully appealing her arrest.',
#  ' What a fire now enjoys national and international renown.',
#  ' and huge bull had been made by the fact of the water, the water of time.',
#  ' At the bottom between Golden and Golden Shoes, it continues as Manchester Shoes.',
#  ' She must have noted your lack of appetite.',
#  ' Let me have the desk.',
#  ' He fled, but only got as far as Greenwich before being captured.',
#  ' The castle is of the Mute and Baile type.',
#  ' Wisdom is the wealth of the wise.',
#  ' The old man said nothing.',
#  ' A putto sits at her side clutching more arrows.',
#  ' You do it.',
#  ' The quick box jumped on the sleeping cat.',
#  ' All winners are highlighted.',
#  ' So it increased the size of the council by one seat.',
#  ' This swallow is tutoring without internet connection and has a swarm of followers.',
#  ' He is the current manager of Saudi Pro League Club Abha.',
#  ' In this game, knights rely their power to friendly pieces.',
#  ' He also proposes giving Samaritan to the government, although Garrison hesitates on it.',
#  " As Mezina departed, Nezia's tail became trapped under a boulder.",
#  ' To the north of the site is the Sierra de Guadalupe',
#  ' He played for the youth categories of real bettys.',
#  ' It drew a drop of blood.',
#  ' These expectations however never happened.',
#  ' Bill decided that management should know about this incident.',
#  ' The appearance of the formidable Spanish caleons inspired panic among the dark sailors.',
#  ' The oldest stupid string theory contained open strings was taught one string theory.',
#  ' efficiency.',
#  ' He was a member of the World Economic Forum in Deos.',
#  ' dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi dhanyi d',
#  ' We lit the lantern and walked over to his house.',
#  ' Where did you come from?',
#  ' The Slavic immigrants came to Bohemia with excellent cigar making skills.',
#  ' To all the swimming, to forgive the mind.',
#  ' The birdie and the bush doon the bush.',
#  ' Reinhardt and his two daughters reside in the land park neighborhood of downtown Sacramento.',
#  ' The test river is one of the rivers that has changed over the years.',
#  ' The city is, therefore, well defended by steep slopes to the northeast and west.',
#  ' These sulfide sulfates can be made by at least three methods.',
#  ' Two.',
#  ' I think they perceived the graph in those dormant elements.',
#  ' He started his political career with the membership of Triple Youth Federation.',
#  ' Iran Naq was born into a wealthy family in Lahore in present day Pakistan.',
#  " We don't want him.",
#  ' Stone completed her undergraduate degree in biology and archaeology at the University of Virginia.',
#  ' But they were not there.',
#  ' Her research considers quantum simulation in ultra-cold atomic gases trapped in optical lattices.',
#  ' The south facade was restored with stones and bricks.',
#  ' But that was simply because my eye was tired.',
#  ' It is also known as Bayo Canyon Road.',
#  ' He also received numerous awards for his work.',
#  ' During that period, Mercedes also developed a streamlined car with monocop construction.',
#  ' Goodbye sad boy',
#  ' She attended Lafollette High School in Madison.',
#  ' What would you say is the difference between a language and a dialect?',
#  ' I have one the junior Olympics if not for those meddling kids.',
#  ' It has been recorded prior to Barkley and Connolly leaving the group.',
#  ' Now proceed to critical acclaim from the several newspapers.',
#  ' At one point there were 70 boys.',
#  ' Know what it is nice to meet you.',
#  " Due to the expense of production, it's not being used for the purpose.",
#  ' Her opponent is counselor Irwin Thay.',
#  ' Philip then tells his parents that he was suspended for singing the national anthem.',
#  ' Mazrakeen was officially married three times.',
#  " The sea has lived on in this shell because that's its destiny.",
#  ' Mostly just the hearts of those who are trying to realize their destinies.',
#  ' Sherbrooke wished the group the best and said he was happy for their success.',
#  ' Pregnant women attend anti-natal classes there.',
#  ' you',
#  ' His father was Mathai.',
#  ' Four. Four. Four.',
#  ' Atlas Cinema hosted seductive films during the annual International Istanbul Film Festival.',
#  ' He was arrested within days, placed on trial and found guilty.',
#  " Every source begins with beginner's log.",
#  ' Production assistance on villains are sometimes attached to individual actors or filmmakers.',
#  ' It was later revealed that the letter was a prank, concocted by the exile.',
#  ' The alchemist followed as the boys horse ran for almost half an hour.',
#  ' There are seven or eight stamina and two stamina nodes arranged around the two carpals.',
#  ' Where are the others?',
#  ' He postulated a dispersion theory before his co-worker made his discovery and announcement.',
#  ' Sylvester needed to meditate to clear his mind.',
#  ' Olivia, have you seen my keys?',
#  " The Borough Council's man's office is at Cobalt Business Park in Walsand.",
#  ' It tends to dominate the planned communities where specific habitat requirements are met.',
#  ' If you know your art well, it will never be able to do that to you.',
#  ' Hey!',
#  ' She was part of the team that came fifth in the final.',
#  ' Die Löhne durch die Anonyka von Hitzpater.',
#  " Although everything should be under the state's control, there is a lot of violence in prisons.",
#  " That's some full-man explaining topic.",
#  ' The green match has not been an ordinary match.',
#  ' No single for the original release from the album.',
#  ' According to the Catholic doctrine, the baby may not be killed.',
#  ' These limits served as the Director General of Bangladesh Agricultural Research Institute.',
#  ' At least 41 protesters were killed in the new Singh engagement.',
#  ' Mining exploration has increased the prevalence of invasive species in its habitat.',
#  ' तो आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आप आ',
#  ' Once these roots reach the ground, they grow into woody trunks.',
#  ' He just got a new car for a birthday.',
#  ' Two years later, online publication extended to include the full text of all articles.',
#  ' Are the consequences more humanistic or anti-humanistic?',
#  ' While a simple card is made by her sold only for 5 cents.',
#  ' The chimney and the area around it was recently refurbished following years of neglect.',
#  ' They joined the band during their call.',
#  ' Lennox kills the two agents and informs Dalazal that he also kidnapped Aling.',
#  ' Olivia Coleman appeared in the episode as Lily.',
#  ' Merrimax will produce the film.',
#  ' The wound healed faster than anyone expected.',
#  ' natt klasht with the Hungarian authorities over his actions, who is higher than prohibited.',
#  ' East Canucks High School is located in Howard.',
#  ' From a barriers, they went out to find other churches and school.',
#  ' He was also one of the founders of Taxic Oil Company.',
#  ' How do I feel?',
#  ' You cannot eat the cake and have it too.',
#  ' In his teens would cover artists including Taylor Swift and The Weeknd.',
#  ' In terms of the spoiler, look out for others. I think we will be found to go.',
#  ' Habib Wahid was born and brought up in Dhaka, Bangladesh.',
#  ' It has been presenting awards for writers.',
#  ' The center portion of the dam has since been demolished and the reservoir drained.',
#  ' Did you know that Harry got a new job?',
#  ' I hope you are well.',
#  " I've never seen you here before.",
#  ' The club is the first non-government owned professional baseball club in China.',
#  ' to stuff into their own pockets.',
#  ' Silence is golden.',
#  ' Somebody threw him off a train.',
#  ' He held a large number of business appointments.',
#  ' Cut your code according to the code.',
#  ' Having token of appreciation.',
#  ' The goo dropped the container and the water spilled.',
#  ' It was occupied by the officers below the rank of lieutenant.',
#  ' He was twice elected to the office of Archbishop of Colombo.',
#  ' Guest performances took us on all over Europe and to South America.',
#  ' There is no support for weighing aspect ratios or force feedback controllers.',
#  ' The town was named after the Spanish town for Lumber.',
#  ' He is, however, usually addressed as Lord Stern or Lord Stern of Brentford.',
#  ' They both had used illegal substances before the killing.',
#  ' Arum Plots is the real estate arm of Arum Ventures.',
#  ' از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از ا',
#  ' Mark, would you please give me the Flieswater?',
#  ' He and his family went up north to the Arctic Circle to meet Santa Claus in Finland.',
#  " The General Albert's primary school in Albertan is also named after him.",
#  ' The empty plastic stood on the thin tray.',
#  ' The launch was flawless. All systems were cool except for the Dr. Vance experiment.',
#  ' ლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლ�',
#  ' The author is a blogger and social media phenomenon.',
#  " Maybe because that wasn't really...",
#  ' Karim Daniel grew up on the south side of Chicago.',
#  " We'll schools secondary schools giving a general practical education.",
#  " Cat's whiskers are very sensitive.",
#  " It's situated to the northwest of Townsendry.",
#  ' This is also the first space flight for Moorer and Barron.',
#  ' There are three wings.',
#  ' The closet door stuck a little as he pulled it open revealing a bare wooden floor covered on one side by a stack of old shoes boxes.',
#  ' Other cast members include Donna Reed and Barry Nelson.',
#  ' Four centuries after her death, Welshman cried out,',
#  ' 4. 7 times stand up and hit',
#  " I'll leave you with the most famous.",
#  ' She was later strapped.',
#  ' Everything honors and he vanished around the corner.',
#  ' In recent years the event has usually been held in February.',
#  " I wouldn't take that too seriously.",
#  ' The show then migrated to the ground in Teotard, Los Angeles.',
#  ' Words are in my not so humble opinion, are most inexhaustible source of magic.',
#  ' It is also used to emulate sound generated by obsolete electronic equipment.',
#  ' Cardinal Truches even suggested that Hosea was a candidate for the papacy.',
#  ' He replaced Alexander Ruel.',
#  ' The mixture will produce a chlorine solution of approximately 500 milligrams per liter.',
#  ' You need so much to go right and things when right for me today.',
#  ' This interpretation is not objective.',
#  ' I always end up soft throwing.',
#  ' The motorcycle made a loud noise.',
#  " You just don't want to watch this video.",
#  ' The boy wanted to believe that his work had simply become separated from him by accident.',
#  ' Have you ever heard the national anthem of South Korea?',
#  ' This was stopped by the instruction of the Emperor.',
#  ' Lemon said the non-the teams were profitable.',
#  ' It was the first event under the Kings of Colosseum chronology.',
#  ' So, a what we the next to go.',
#  ' Servants send Leonardo away and the guests begin arriving for the wedding.',
#  ' When I returned to the common, the sun was setting.',
#  ' The locals near the mine have reported damages to their houses.',
#  ' The child with the helmet on his head rides the bike.',
#  ' I luck eyes with a fish in the tank.',
#  ' Kruan and Borea were not initially interested in fitting patterns on the work.',
#  ' I need a pacifier for my baby.',
#  ' Setshenov, 1 Moscow State Medical University',
#  ' Meanwhile, Regi frantically tries to get a state of execution.',
#  ' Right of the interstate is to boot in general retro light bulbs.',
#  ' It does not look good.',
#  ' Peace be unto you and grace before the Lord.',
#  ' if you have to wait until the war is over then wait',
#  ' इस आंकोले जाएक डाजी गाश्मे',
#  " Let's do this in chronological order.",
#  ' What good will that do?',
#  ' Several other tracks were used to promote the album across various mediums.',
#  ' But not for long.',
#  ' She was then appointed lecturer in psychology at the university.',
#  ' It was a problem while I was sitting over there.',
#  " Sherman's mother-in-law Margaret Otting married, secondly, John Porter, another sign of the Portsmouth Compact.",
#  ' He continues to be an active board member of association.',
#  " In 1969, the first man set foot on the moon's surface.",
#  ' The path will be known as the Northern Strand Community Trail.',
#  " He's been crying for five minutes.",
#  ' The spots were reallocated to the world rankings.',
#  ' It is a sole department within the Gordon Heights Fire District.',
#  ' A friend to everybody is a friend to nobody.',
#  " St. Gubain's financial performance was adversely affected by the economic and petrol crisis.",
#  ' Stuart was a two-time team captain in all of the seven-selection basketball.',
#  " You haven't got your wings yet.",
#  " Luke served as Matt's best man at his wedding.",
#  ' His son Assemblyman Toli Butjo was appointed to the Senate seat.',
#  ' The Royal Danish Chancellor has issued an arrest warrant for Hans Nielsen Hogg.',
#  ' The mouth of the Peg River is along the southwestern shore of Pago Bay.',
#  ' It also has glass cut windows and antique wooden furniture.',
#  ' like a fish out of water',
#  " The Little Mountain Reunion is one of South Carolina's oldest folk festivals.",
#  ' This is something I want to encourage.',
#  ' Soral study medicine at the University of Adelaide.',
#  ' He is an active justice of the Supreme Court of Ghana.',
#  " You can't have your keg in need too.",
#  ' It is found near streams.',
#  ' The Cawson Tuff Elementary School is named in his honour.',
#  ' sans has produced something extraordinary.',
#  ' and the sand and graphite had been flung far and near in every direction.',
#  ' AdWords made more appearances for Lakeside and also wrote some meetings for Eastbourne Eagles.',
#  ' They became lifelong freedoms.',
#  ' Realist, he shall heed and he exclaims I see.',
#  ' Select between the line x and the line y.',
#  " And I'm certain you'll find it, the outcome is the same.",
#  ' Please consult your physician if you experience any side effects.',
#  ' The two platforms are now linked by a footbridge.',
#  ' Experts of geology agree. Yes, a tsunami was just a herald of the imminent apocalypse.',
#  ' Antarctica is cold at this time of year.',
#  ' Attached to the white room is a command module trainer.',
#  ' A man stands with on foot elevated onto a step in front of a small fire.',
#  ' He is also the provincial secretary of the South African Communist Party.',
#  ' The pin number is 3 7 2 6',
#  ' To do that successfully I must have no fear of failure.',
#  ' The ship had sailed three more times prior to capsizing during its fourth voyage.',
#  ' He immediately left the bar and headed home.',
#  ' Initially, she performed in small supportive roles.',
#  ' The thought was so gentle to him that he forgot about the heat and went forward.',
#  ' At least six T-winter locomotives have been preserved.',
#  " System power does not need to be exploited here, so it's highly likely.",
#  ' It was first observed of the Hawaiian Islands and Tehiti.',
#  ' It was also announced that this new team would be affiliated with Roche Racing.',
#  ' He played for the Delhi Derwels in the previous seasons.',
#  " I don't want anything for myself.",
#  ' Formal clinical trials in depressed patients have not been reported.',
#  ' Japan is a society and watching information.',
#  ' The second half of the cracker is then added on top.',
#  ' Beachly inner rates the 7 network factual series Beach Cups.',
#  ' His body was covered with branches until it was discovered by two men.',
#  ' William Howard was born at Hinsburg Bermond.',
#  ' And Glicanism and Reformed Christian are also present in significant numbers.',
#  ' The new building was designed in the collegiate Gothic architectural style.',
#  ' Most patients exhibit abnormal sleep patterns characterized by insomnia and daytime drowsiness.',
#  ' The first priority was to build an imposing church.',
#  ' They looked for the falling mess, but found nothing.',
#  ' It was so small and undeveloped.',
#  ' We could not believe a ball was going that far.',
#  ' Ibrahim Karimal Braw is yellow eye actually into playing.',
#  ' It seems all them wise.',
#  ' Included in Anacostia Park is Canill War Park and Aquatic Garden and Canill War March.',
#  " A part of me is also trying to come to terms with the fact that I won't be able to travel as much anymore.",
#  ' He was survived by his third wife, Eda, a daughter and two step-sons.',
#  ' Today the entire area is covered with housing.',
#  ' Can you imagine something more beautiful than a plastic bag swooping and floating in a breeze?',
#  ' Seoul has two main airports, the Indian International Airport as well as the Gimpo International Airport.',
#  ' It has inherent support for runtime cast validation.',
#  ' The engineers spent the phony war periods working on defensive positions.',
#  ' I thought you were going to teach me some of the things you know.',
#  ' The four winners will go to the next round.',
#  " This book, Familiar, for narrating history of companions of Muhammad's age.",
#  " Maybe she didn't even remember him.",
#  ' The town is believed to be the birthplace of asparagus juice in the New World.',
#  ' The woman shook her head.',
#  ' The rager show published a monthly newsletter for subscribers called After Dark.',
#  ' A group of people, one of them with the guitar, were sitting by the campfire and singing songs.',
#  ' Elle ressemble à toi, elle va venir aussi.',
#  ' No.',
#  ' Tomorrow, start your camp and buy a horse.',
#  " Let's stop this another command to save.",
#  ' His poetry has features of a report, often with a distinct narrative storyline.',
#  ' Ferdale contains virtually no commercial industrial development, with nearby Saskatoon offering these services.',
#  ' But he prevailed. I did.',
#  ' They are the first to start the next round.',
#  ' He earned extra money by renting a room in his house to a lodger.',
#  ' Madifal Madness was also included in the arcade game Ultra Pin.',
#  ' As soon as he saw me among the crowd he called me to come down.',
#  ' Institutional corruption is not limited to national-scale institutions.',
#  ' In this period, three family members left the group.',
#  ' To calibrate the motion capture system, please do a T-pose.',
#  ' What is the height, length and width of the container?',
#  ' She has a variety of techniques.',
#  ' A short, distinct and pointed style the opposite of lagittow.',
#  ' There were lights in the upper windows of the houses when the people went to bed.',
#  ' Watch this eye heal.',
#  ' Anna Olson asked about the acceptance of the word alliteration.',
#  ' Providing local and express service between Mexico and Guatemala City.',
#  ' Do you know any silicon valley billion noise?',
#  ' Vous y prévètes, vous essayez de distribuer en disclé, en faisant le tap.',
#  ' nautishe dhe aniqua cooling of its surface.',
#  ' Out of the four, Venkman is the default coursebuster that is selected.',
#  ' She could not sit still.',
#  ' She serves on the advisory board of the Global Diplomatic Forum.',
#  ' It seemed so safe and true.',
#  ' The British continue to use this site as a hospital.',
#  ' I read only what the birds wanted to tell me.',
#  ' Please be humble.',
#  ' Aux autres organisations de la nouvelle, ont des récits comme leur désir.',
#  ' The builder placed the brick onto the plank of wood so it would bend into shape.',
#  ' Det volume budder en gris meget forrørende.',
#  ' Cuba is in the fourth stage of demographic transition.',
#  ' I told you that your dream was a difficult one.',
#  ' Should I understand the emerald tablet the boy asked?',
#  ' The flight to Australia was long.',
#  ' The terminology is made confusing by the etymology of these words.',
#  ' It could be great.',
#  ' Their program consisted of several parts.',
#  " I could not judge for her actions, but I believe that she's right.",
#  ' This went from McLoone to the Isley Alphabet.',
#  " Its motto on the nameplate below the title is one of America's great newspapers.",
#  ' Most of these subjects were found in Devon and Cornwall.',
#  ' The grass is always greener on the other side of the fence.',
#  ' I had a week long wave of the DMSI at the Olympiad later.',
#  ' It belongs to the commander of the military.',
#  ' More recently, advances in sensing and computing technology have given rise predictive maintenance.',
#  ' Michael was involved in all three games.',
#  " What's the matter with you?",
#  ' Aki hai elmaltere krettings on en south e black mark geld forward and into our sui.',
#  ' For a certain time, it had not occurred to him that it might be no loop.',
#  ' Construction on the dam continued for three more years.',
#  " It's country, city, and other cities on back.",
#  ' It has no other outlet.',
#  " Don't worry, I talk to get home safely.",
#  ' That is quite another matter.',
#  ' What may I do?',
#  ' hunk is of 5.1 background',
#  ' The wish found is the thin company of Canada.',
#  ' Have we grown allowed? We have lost.',
#  ' Jet is not a mineral, but rather a mineral water.',
#  ' These pieces are on the rain from July to April.',
#  ' She was also a philanthropist',
#  ' It was called the modular commission after.',
#  ' The all exit left.',
#  ' Kamu ada 4 kakak.',
#  ' Even with night vision goggles, no target was in sight.',
#  ' He is considered one of the most important drainage painters of the Bydron Mayer period.',
#  ' Simon says had an extremely negative reception by critics.',
#  ' What did your family have to say about it?',
#  ' A principle concern about the plant is that it can be sufficient or great proof.',
#  ' He was replaced on bass guitar by Chastin Kul.',
#  " I'd add a separate subsection which deals with this aspect.",
#  ' Operation of the trunk line continued on the wooden trusses.',
#  ' Magnation fluoride is transparent over an extremely wide range of wavelengths.',
#  ' 4 giant packing shits, turret fresh packet potatoes and deliver them on turret railroad cars.',
#  ' The other 14 campuses are two-year campuses referred to collectively as the University College.',
#  " It's too bad that he quickly going to forget my name.",
#  ' One picture in the gallery shows how the Jens slaves erected the statue of Admiral Thompson.',
#  ' Imperial Diet',
#  ' The resulting company is the StarTech Security Corporation.',
#  ' Bitcoin mining can be done with graphics cards or with specialized hardware.',
#  ' They also leave the national ranking.',
#  ' Charles Graves, Bishop of Numeric.',
#  ' And at that I told him and he took my place.',
#  " I thought I'd give the kids a treat.",
#  " I say I don't deny it showing the pictures.",
#  ' Hold your nose to keep the smear from disabling your motor functions.',
#  ' That sounds like their problem.',
#  ' Historically, there was no clearly defined boundary in this part of the Arabian Peninsula.',
#  ' Marshall Shaffer of Slash Film gave the film an 8 out of 10.',
#  ' How can you say that?',
#  ' His style began to resemble Michael Tamaskinos.',
#  ' He is also capable of firing lightning bolts with immense disruptive power.',
#  ' We claim to wake its in England only innings as for the web beat and perhaps',
#  " She didn't much. She did really well.",
#  ' He met the organizers of the protests and agreed to create two working groups.',
#  ' The ball struck the foul pole well above the green monster.',
#  ' Only Camden, Thomas Garrett and Goldfield South Ezekiel Baker were uncontested.',
#  ' It is a charity school whose fees are calculated on a means test.',
#  " Someone's away while I was there and other people came.",
#  ' Tether!',
#  ' The Kira Kanate was located mainly in the historical and geographical region of Kira.',
#  ' Delivery at the site is above sea level.',
#  ' Tobias tried to inject Contempt into his tone.',
#  ' I have to work this Saturday.',
#  " Don't play the runes, found the squeaky glade with glating on their nose.",
#  ' When the building tossed, he sailed a bit. The boy troubled at what he saw.',
#  ' Democrat Amber Baker won with the open seat.',
#  ' Bukitia kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa k',
#  ' Trench was born in Belize city in British Honduras.',
#  ' The already phase of life moves faster.',
#  ' At one time railway lines diverged from rugby station in seven different directions.',
#  ' Czech Republic entered two shooters into the Paralympic competition.',
#  ' Roger Williams wrote the screenplay and shared story credit with the Revit.',
#  ' This festival was to be a charity fundraiser for the year.',
#  ' These extra guards were inserted randomly into bugs.',
#  ' And we want back to Australia.',
#  ' Permit me to introduce you to Her Majesty the Queen.',
#  ' In origin, heroin was supposed to be the non-addictive morphine substitute.',
#  ' She is of Mexican descent.',
#  " I'm sure there is not on this.",
#  " Also don't learn from history, I don't repeat it.",
#  ' از از از از سارن از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از از',
#  ' Untuk simplicitas, gear inch-shaft adalah biasanya diperlukan ke nilai yang terbaru.',
#  ' If we actually do want it solved, it will be.',
#  ' The fruit of a fig tree is apple shaped.',
#  ' Thou exchange is no robbery.',
#  ' What you eat today walks and talks tomorrow.',
#  ' The water then flows out of the squamps as the Luwapola River.',
#  " Why didn't you say something?",
#  ' Have you seen Omar?',
#  ' I could go on for days about the delicious ones produced in this part of the world.',
#  ' The Philadelphia Inquirer LinkedIn City Playout of the Year.',
#  ' Horse need a subject to special rules',
#  ' The Swedes were unable to use their vehicles which were stuck in the mud.',
#  ' The act did not prohibit paying a representative to appear in the court.',
#  ' Can we please sleep now?',
#  ' He was convicted in Venice to Cyprus for seven years for punishment.',
#  ' The couple have two children, a daughter, Sophia, Rosalinda, and a son, Mateo Bravery.',
#  ' None of the three referendums reach the quorum of the majority of those entitled.',
#  ' Turpin succeeded Indira Samarasipkara who saw the university through a period of strong growth.',
#  ' Here I am between my flak and my treasure the boy toss.',
#  ' This failure has led to 16 power plants having zero days of cold stock.',
#  ' Why does that plane keep going over?',
#  " Okay, I've done this before with a virtual box with good results.",
#  ' The application was approved in February.',
#  ' Henry Tarleton tells where he had sound training in Latin.',
#  " It was discontinued due to scheduling conflicts involved in Lewis's return to terrestrial radio.",
#  ' Her family was from Brionza.',
#  ' What did he eat for dinner?',
#  ' That was my draw to science.',
#  ' He is considered a master of shallow scuro.',
#  ' It then returns to the church, ascends at the altar and spears.',
#  " You're gonna have to do this for a minute.",
#  ' The Jaws X10 F-Di.',
#  ' My niece can help you with that.',
#  " Mae'r ddweud o'r ddweud.",
#  ' Hope for the best and prepare for the worst.',
#  ' Initially the weight loss was obtained strictly by diet.',
#  ' All were owned by the Everett Moore Syndicate.',
#  " We'll eat rain tomorrow.",
#  ' Do best with me in lip.',
#  ' Yusiele Petri took her place as acting director.',
#  ' Perjalanan Biver berbual di antara keadaan es di tengah kota.',
#  ' The track resurfacing was also completed.',
#  ' Hitmarsh was aware of the importance of electron microscopy in biological research.',
#  ' Shinhaba, Spongebob.',
#  ' This bridge is unofficially referred to as Blackwater Bridge by collision forces operating there.',
#  ' It is responsible for water supply and management of water resources in Mahastra.',
#  ' This is the first phase of the job he said.',
#  ' The two large dogs are running through sand.',
#  " The actor's authentic facial expression was convincing the jury.",
#  ' All songs written by Neil Morse except were noted.',
#  ' ḍ្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្�',
#  ' Tal is also said to have cause congestion and accidents in the area.',
#  ' Cursed and shrugged their shoulders.',
#  ' The authors approved of the contrasting styles.',
#  ' She crouched down to lay her shoes in spots that are fully clever.',
#  ' The city took its name after one of these colonnades, Phanagoras.',
#  ' Guess the result from the first course.',
#  " They don't want me to play.",
#  ' Can I pay in cash?',
#  " You can tell me why you came here and show you the project I've been working on.",
#  " Mae'r cyfaint yn ymddiadol yn y ddweud yma.",
#  ' I was scared but wasted no time in going out and crossing the bridge to the sand pits.',
#  ' Due to its path, scientists theorized that Kotec was an Oort cloud object.',
#  ' Use NAT today what tomorrow will need.',
#  ' A whiff of it will cure the most stubborn cold.',
#  ' Writing across the curriculum is a school-wide initiative.',
#  ' He played an important role in the field of education in the Netherlands.',
#  ' The layout part does not change its spots.',
#  ' The coastal economy revolved around shipping and trade.',
#  ' Fool is gravity fed to the carburetor.',
#  ' He subsequently joined the Stockton Kings.',
#  ' She begged home, smiling all the way, knowing that she had won.',
#  ' His hand was aborted and adjusted but he listened to his heart.',
#  ' Eight winners of the previous round progressed to the quarter finals.',
#  ' The inmates are transformed by the symbiotes into creatures that resemble doppelganger.',
#  ' It is a tourist destination and fishing, camping and other activities are permitted.',
#  " I'm sorry for it.",
#  ' Currently is training a new crop of players in Hindu, Gankana in Mumbai.',
#  ' They had three children, Jeff, Kate and Kimberly.',
#  ' paid for the ride',
#  ' The table was adorned with lavish decorations.',
#  ' Notably, it provided the harsh sounds on the track antenna.',
#  ' From an early age he stood at piano with his mother as well as trumpet.',
#  ' The boy loop around here at the date palms.',
#  ' Ne vaut pas se mettre en train de faire une truie grise, pas de se mettre dans le monde.',
#  ' Their presence was necessary because of strong civil unrest in the area.',
#  ' The newspaper, Octicus had prepared everyone for the reception of the idea.',
#  ' The aftermath of the destruction of Florida shapes the lives of several characters.',
#  ' The Adokha campus has gained a commendable reputation in a short time.',
#  ' It is the most comprehensive eastern Armenian dictionary written in the Reformed Armenian orthography.',
#  ' Braddock height is part of the Middleton School District.',
#  ' Men that are not included in the line, they reserve Militia Nevermine farewell.',
#  ' Plusive stops become nasal stops before nasal stops.',
#  ' After the season, he became a free agent.',
#  ' He was killed by Nikaya.',
#  ' The sun shines on both sides of the H.',
#  " It's hard to compare something necessary on Monday with something I'm excited about.",
#  ' There was also prosperous manufacture of starch blumming to the LaGrine family.',
#  ' The following are examples of prefixes in the correct',
#  ' I give the woman credit.',
#  ' They are very docile and placid animals and can be approached easily.',
#  ' وانتظر لها تحديثة كوجاب رومسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيسيس',
#  ' Where did you find that apple?',
#  ' The line ran west from Sanford to Taveres on Lake Usis.',
#  ' A locomotive depot and staff toilets were built to the north.',
#  ' Jackson accused various political enemies of being behind Lawrence.',
#  ' 어디가?',
#  ' Maddox has two children and two stepchildren.',
#  ' The family moved to Florida once the two daughters go pro.',
#  ' The mathematical details of the deformation parameters are as follows.',
#  ' Another pot. Try the teapot.',
#  ' That damn mouse could sense my anger.',
#  ' There are obvious drawbacks in the theory.',
#  ' You know gifts are better finished free.',
#  ' Martinage abandons her after knowing that she is pregnant with his child.',
#  ' ḍᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃᵃ�',
#  ' The school organizes annual trips ranging from Snowdonia, Wales to Ouzel, France and beyond.',
#  ' Through Effingham it is Fayette Avenue and Willow Street.',
#  ' It grows along the borders of lakes, ponds and streams and in marshes.',
#  ' To her amazement she found a supermarket trolley lying on the seabed.',
#  ' All songs written by Dave Windorf unless noted otherwise.',
#  ' The news was chilling to say the least.',
#  ' I have Celtic ancestry.',
#  ' The Dixie Chicks were bloodlusted by thousands of country radio stations.',
#  ' Since then, the double-core, the new underpriced has come back to us.',
#  " That's true, the boy fought.",
#  ' It needs full sun to partial shade.',
#  ' Attempting to fit the data too carefully leads to overfitting.',
#  ' Nickel Battle-y, see ya there boy.',
#  ' The motor in was built to accommodate car travelers traveling through Kinsen.',
#  ' All of the bus models are limited editions and network collectors.',
#  ' I will feed both of the surfaces. The disgusting is sticky.',
#  ' Labour groups, while overwhelmingly supportive, expressed a set of reservations.',
#  ' Union consent was cited as a major hurdle for negotiators to clear.',
#  ' I got drunk yesterday and thought I would as a computer',
#  ' A baraita taught that Zellofehads daughters were wise Torah students and righteous',
#  ' اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای اینجای',
#  ' The original name of the hermitage was Gorham Zimki Carpo.',
#  ' I actually like it, but clearly this is the way of them.',
#  ' Wire Gully covers round.',
#  ' Earlier in his career, he was district attorney of Kenosha County.',
#  ' This segment science bunch has doth in its puppet from explaining food science.',
#  ' Botha School is a part of Clearview Public Schools.',
#  ' The questioner is too simplistic.',
#  ' What is the matter?',
#  ' He also gave master classes in various countries.',
#  ' The company has its headquarters in Bengaluru.',
#  ' In a little while.',
#  " Especially Liddell Hart wrote many books about the subject, partly propagating Fuller's theories.",
#  ' His second novel is Altosir.',
#  ' It is one of the most photographed site in the area.',
#  ' Kamu lebih baik dapat teman kamu',
#  ' This is the second novel written by Gillham.',
#  ' I heard the long word I hope it lived. The show was actually being filmed in New Zealand.',
#  ' For example, save the current file called to the search menu',
#  ' Its smaller, more common class of egg liners is the narrow body or single-aisers egg omelet.',
#  " It's never entered into effect.",
#  ' I wish I could go back to the hospital.',
#  ' Madonna g-rated around her dancers while playing with the harp.',
#  ' His opponent is Jury Rafael Caterpire and Antonio Mendoza.',
#  ' Click on the top, but was dropped again almost immediately.',
#  ' He has also won gold with Team Ontario at the Canada Games.',
#  ' All three houses were originally one-story residences.',
#  ' The watermaster class water equality standard set by the environment agency.',
#  " Don't press the red button.",
#  ' Repression was conducted by the Czech Intussessor and other state organs.',
#  ' The illumination creates a cozy atmosphere.',
#  ' John looked out the window of the show house, happy he had mortgage approval, but worried about the repayments.',
#  ' She note the Randa was not looking for revenge.',
#  ' He also sits on the Northwest Regional Leaders Board.',
#  ' If anything can go wrong, it will.',
#  ' The suburb features many areas of greenery with native trees characterizing most streets.',
#  " There's no falling around.",
#  ' I have the diet of a kid who found $20.',
#  ' Their albums occupy the top places in the final year charts.',
#  ' Another recurring theme on the island of energy divisions in the societies.',
#  ' And the women in a yellow shirt standing in the doorway.',
#  ' Kathy took 210 pounds out of her bank account.',
#  ' Make here while the sun shines.',
#  ' ini sangat berharga pada july 1 tahun',
#  ' Clustering and limit points are also defined for the related optical filters.',
#  ' Desperate diseases must have desperate remedies.',
#  " Yes, he's replied the library.",
#  ' Henderson was taking it in.',
#  ' But we just performed this.',
#  ' Our group played guitars while the others randomly hit resonant objects.',
#  ' Nothing lost for lack of asking.',
#  ' It would be ideal if the Wi-Fi were correct.',
#  ' Can I get you a drink?',
#  ' to fall into the house with a door to blurt out something to put it bluntly.',
#  ' Today benchmark will be introduced as a recreation area.',
#  ' Now the group participates in the anti-capulist movement and anti-war movements.',
#  ' I want my baby to look like you.',
#  ' Then the tool went off to have some more tea.',
#  ' Some scientists believe the origin of this oscillating signal to be a neutron star.',
#  ' How do I close this window?',
#  ' That all for Masterise, illness or according to some sources a snake bite.',
#  ' Ako mtunia kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa kwa k',
#  " You're not standing still, huh?",
#  ' ន្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្្�',
#  ' I had already scrubbed the appearance of the colossal bulk which was embedded in the ground.',
#  ' The university belongs to the Council of Reactor of Tradition and Challenge Universities.',
#  ' The next day, the mine opened and work begins.',
#  ' His father died later that year.',
#  ' One of them, Arshaneddin Abley, would secede him on the throne.',
#  ' During her life, she was an active member of the League of Women Voters.',
#  ' Davidson studied British politics and legislative studies at the University of Hull.',
#  ' It is a surprise district.',
#  ' Feeling bad but offers to team with her in a karaoke context.',
#  ' They were dwelling for control of the Republican Party.',
#  ' Primary endosymbiosis involves the engulfment of a bacterium by another free living organism.',
#  ' her husband crushed her larynx and killed her.',
#  ' The album received Universal Acrim form reviews.',
#  ' List of unlicensed and prototype new games',
#  ' Usually, town members adorn the town streets with colorful decorations and other things.',
#  ' The boy drew back his head with pride.',
#  ' Re-married three times',
#  ' He had suddenly remembered that, in Tarefa, there was an old woman who interpreted dreams.',
#  ' It reminds to that their third best linchu album',
#  ' When used to pay laborers, recorded wages in the Asian world range widely.',
#  ' Tidak ada yang mencintai dia.',
#  ' ლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლლ�',
#  " Stout's political career started in his election to the Otago Provincial Council.",
#  ' The boy could certainly resist causing that kind of anxiety for the baker.',
#  ' Fake stones shine but cost little.',
#  " One of the world's biggest problems is the growth of the human population.",
#  ' Almost every other house in Amos has a person who is standing uproar.',
#  ' And who are you?',
#  ' Same year, he left the city and joined the Partitions in the countryside.',
#  ' He was 21 and she was 20.',
#  ' Slanigan was later kicked out of the university.',
#  ' It offers a trail system for horseback riding and hiking.',
#  ' A corda da data é ainda setada.',
#  ' I found out her real name.',
#  ' أم لاسي أم لا نور تخصوصا وقادر وصدقاء ومعالقات المنطقة؟',
#  ' What he said reminded the boy of the old king',
#  ' I need to refer to my notes at this point.',
#  ' the boil of the happiness.',
#  ' He graduated cum laude with a Bachelor of Science in Applied Mathematics.',
#  ' She conducted negotiations with the prison commander on their behalf.',
#  ' דלקטוטייפ הוא סקולקטת נרדי קלארנס ריבר בי-הרמן-בקלר',
#  'お腹が空いてる',
#  ' The credits are all by showing the clips of their animon.',
#  ' The album is one of the free part series of albums by ACON.',
#  ' Hey, what do you say?',
#  ' The agreed text was in 3 parts.',
#  ' The rhythm is typically played as a snare rim pattern in Bosa Nova music.',
#  ' Characters can be trained in spells from multiple different colors of magic.',
#  ' And what became of him?',
#  ' Compare the checks and to verify its integrity.',
#  ' Why do you want to see me?',
#  ' It was the tallest reinforced concrete structure in Moscow.',
#  " Aren't the two rather intertwined?",
#  ' Also, there was a decrease in trade interests between East and West.',
#  ' Many see this as a sign of growing the conciliation on the grass roots level.',
#  ' It took him a while to get to the office.',
#  ...]

# %%
wer_metric = load("wer")

wer_ortho = 100 * wer_metric.compute(
    references=cv_11_test["sentence"], predictions=all_predictions
)

# %%
wer_ortho
# Out:
# 28.32954159148558

# %%
normalizer = BasicTextNormalizer()

# compute normalised WER
all_predictions_norm = [normalizer(pred) for pred in all_predictions]
all_references_norm = [normalizer(label) for label in cv_11_test["sentence"]]

# filtering step to only evaluate the samples that correspond to non-zero references
all_predictions_norm = [
    all_predictions_norm[i]
    for i in range(len(all_predictions_norm))
    if len(all_references_norm[i]) > 0
]
all_references_norm = [
    all_references_norm[i]
    for i in range(len(all_references_norm))
    if len(all_references_norm[i]) > 0
]

wer = 100 * wer_metric.compute(
    references=all_references_norm, predictions=all_predictions_norm
)

# %%
wer
# Out:
# 24.299071426276384
